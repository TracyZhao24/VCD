# %%
import matplotlib.pyplot as plt

# %%
results= {
    "Baseline": 0.8186666666666667,
    "VCD": 0.847,
    "Segment": 0.831,
    "Color\nJitter": 0.8123333333333334,
#    "GB\n15": 0.841,
    "Gaussian\nBlur": 0.847,
    "Ensemble": 0.858
}

# %%
plt.bar(results.keys(), results.values())
#plt.xlabel('Methods')
plt.ylabel('Scores')
plt.title('POPE Hallunication Mitigation Methods \nCOCO dataset')
#plt.xticks(rotation=)
plt.ylim(0.8, 0.87)
plt.show()
